# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src/data')))
sys.path.append(os.path.abspath(os.path.join('..', 'src/eda')))
from eda import *
from sklearn.datasets import fetch_openml
from dataset_interface import DataInterface
from data_loader import OpenMLDataLoader

# %matplotlib inline


iris = DataInterface(OpenMLDataLoader(dataset_name='iris'))

#iris.preprocess_data()

fig = figure_missing_values(iris.data, (8,8))
fig = figure_target_distribution(iris.data)
fig = figure_feature_distributions(iris.data)
fig = figure_correlation_matrix(iris.data)
fig = figure_pairplot(iris.data, sample_size=100)
fig = figure_tsne(iris.data, perplexity=30)
plt.show()
