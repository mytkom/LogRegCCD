# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))
from eda import *
from sklearn.datasets import fetch_openml
from dataset_interface import DatasetInterface

iris = DatasetInterface()
iris.fetch_from_openml('iris')

# iris.preprocess_data(
#     convert_to_binary=True,
#     encode_labels=True,
#     standardize_data=True,
#     missing_values_strategy='mean',
#     remove_correlated_features=True,
#     add_dummy_features=True
# )

plot_missing_values(iris)
plot_target_distribution(iris)
plot_feature_distributions(iris)
plot_correlation_matrix(iris)
plot_pairplot(iris, sample_size=100)
plot_tsne(iris, perplexity=30)
