# %%
from src.eda.eda import (
    print_basic_info, print_target_distribution_info, figure_missing_values,
    figure_target_distribution, figure_feature_distributions, figure_correlation_matrix,
    figure_pairplot, figure_tsne, feature_variance_explained, figure_msno_matrix
)
from src.data.dataset_interface import DataInterface
from src.data.data_loader import OpenMLDataLoader

# %%
dataset_name = 'arcene'
data_loader = OpenMLDataLoader(dataset_name=dataset_name, version=1)
data_interface = DataInterface(data_loader=data_loader, dataset_name=dataset_name)
print_basic_info(data_interface.data)
# Out:
# Dataset shape:
# (200, 10000)
#
# Dataset features count:
# 10000
#
# Dataset observation count:
# 200
#
# Dataset overview:
#     V1  V2   V3   V4  V5   V6   V7  V8  V9  V10  ...  V9991  V9992  V9993  \
# 0    0  71    0   95   0  538  404  20   0    0  ...    255    570     86
# 1    0  41   82  165  60  554  379   0  71    0  ...    213    605     69
# 2    0   0    1   40   0  451  402   0   0    0  ...    235    593     28
# 3    0  56   44  275  14  511  470   0   0    0  ...     91    600      0
# 4  105   0  141  348   0  268  329   0   0    1  ...    813      0      0
#
#    V9994  V9995  V9996  V9997  V9998  V9999  V10000
# 0      0     36      0     80      0      0     524
# 1      7    473      0     57      0    284     423
# 2      0     24      0     90      0     34     508
# 3     26     86      0    102      0      0     469
# 4      0      0    190    301      0      0     354
#
# [5 rows x 10000 columns]
#
# Dataset description:
#                V1          V2          V3          V4          V5          V6  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    35.385000   37.055000   60.305000  325.425000   17.055000  410.940000
# std     48.755742   37.954905   71.168439  155.169819   27.095068  105.681404
# min      0.000000    0.000000    0.000000    0.000000    0.000000  181.000000
# 25%      0.000000    0.750000    0.000000  211.500000    0.000000  311.750000
# 50%     10.500000   27.500000   23.500000  334.000000    0.000000  431.500000
# 75%     54.000000   59.250000  116.000000  433.750000   29.500000  497.000000
# max    194.000000  218.000000  240.000000  705.000000  109.000000  635.000000
#
#                V7          V8          V9         V10  ...       V9991  \
# count  200.000000  200.000000  200.000000  200.000000  ...  200.000000
# mean   226.310000    7.695000   48.795000   70.765000  ...  376.420000
# std    181.533678   14.893659   58.164927   96.738469  ...  268.328464
# min      0.000000    0.000000    0.000000    0.000000  ...   61.000000
# 25%      0.000000    0.000000    0.000000    0.000000  ...  191.000000
# 50%    245.500000    0.000000   25.500000    8.000000  ...  257.500000
# 75%    410.250000    9.000000   79.250000  143.250000  ...  597.750000
# max    501.000000   74.000000  202.000000  425.000000  ...  969.000000
#
#             V9992       V9993       V9994       V9995       V9996       V9997  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   383.355000   46.150000   18.475000  107.170000  177.870000  202.205000
# std    234.985489   48.948619   24.981186  157.800399  142.621025  118.424172
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    236.250000    0.000000    0.000000    0.000000    0.000000   92.750000
# 50%    459.000000   37.000000    0.000000   44.500000  214.500000  183.500000
# 75%    574.250000   81.000000   35.250000  130.000000  283.250000  314.500000
# max    692.000000  200.000000   90.000000  656.000000  509.000000  423.000000
#
#             V9998       V9999      V10000
# count  200.000000  200.000000  200.000000
# mean     0.690000   87.965000  361.650000
# std      3.367581  111.476224  104.970336
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000  312.750000
# 50%      0.000000   38.500000  361.000000
# 75%      0.000000  159.250000  446.000000
# max     24.000000  491.000000  533.000000
#
# [8 rows x 10000 columns]
#
# Dataset missing values count:
# 0
#
# Constant features count:
# 39
#
# Labels description:
# count     200
# unique      2
# top         2
# freq      112
# Name: Class, dtype: object
#
# Labels missing values count:
# 0

# %%
figure = figure_correlation_matrix(data_interface.data, 200)

# %%
data_interface.preprocess_data()
# Out:
# Removed 39 constant features.
# Removed 6175 correlated features.

# %%
print_basic_info(data_interface.data)
# Out:
# Dataset shape:
# (200, 3786)
#
# Dataset features count:
# 3786
#
# Dataset observation count:
# 200
#
# Dataset overview:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.727582  0.896595 -0.849482 -1.488712 -0.631030  1.205310  0.981283
# 1 -0.727582  0.104200  0.305605 -1.036462  1.588952  1.357088  0.843222
# 2 -0.727582 -0.978740 -0.835396 -1.844052 -0.631030  0.380015  0.970238
# 3 -0.727582  0.500398 -0.229679 -0.325782 -0.113034  0.949184  1.345764
# 4  1.431415 -0.978740  1.136705  0.145851 -0.631030 -1.355950  0.567100
#
#          V8        V9       V10  ...     V9953     V9961     V9967     V9968  \
# 0  0.828264 -0.841013 -0.733344  ... -0.574610 -0.301383  2.782706  0.656539
# 1 -0.517959  0.382717 -0.733344  ...  0.795321 -0.301383 -0.198467  1.742155
# 2 -0.517959 -0.841013 -0.733344  ... -0.574610 -0.301383 -0.594567 -0.144749
# 3 -0.517959 -0.841013 -0.733344  ... -0.574610 -0.301383  0.531191 -0.429077
# 4 -0.517959 -0.841013 -0.722981  ... -0.156020 -0.301383 -0.594567  1.406131
#
#       V9969     V9972     V9976     V9988     V9993     V9999
# 0  0.590166 -0.426805 -0.481563 -0.987873  0.816162 -0.791072
# 1 -0.016606 -0.426805 -0.481563  0.300124  0.467987  1.762949
# 2 -0.144348 -0.426805 -0.481563 -0.701652 -0.371727 -0.485309
# 3 -0.144348 -0.426805 -0.481563 -0.456319 -0.945191 -0.791072
# 4 -0.144348 -0.426805  1.757705 -0.967429 -0.945191 -0.791072
#
# [5 rows x 3786 columns]
#
# Dataset description:
#                  V1            V2            V3            V4            V5  \
# count  2.000000e+02  2.000000e+02  2.000000e+02  2.000000e+02  2.000000e+02
# mean   7.105427e-17  2.220446e-18 -5.995204e-17 -6.217249e-17  1.110223e-17
# std    1.002509e+00  1.002509e+00  1.002509e+00  1.002509e+00  1.002509e+00
# min   -7.275819e-01 -9.787401e-01 -8.494823e-01 -2.102481e+00 -6.310299e-01
# 25%   -7.275819e-01 -9.589302e-01 -8.494823e-01 -7.360380e-01 -6.310299e-01
# 50%   -5.116822e-01 -2.523779e-01 -5.184511e-01  5.540071e-02 -6.310299e-01
# 75%    3.827593e-01  5.862403e-01  7.845439e-01  6.998580e-01  4.604613e-01
# max    3.261422e+00  4.779331e+00  2.531261e+00  2.452329e+00  3.401938e+00
#
#                  V6            V7            V8            V9           V10  \
# count  2.000000e+02  2.000000e+02  2.000000e+02  2.000000e+02  2.000000e+02
# mean   3.330669e-17  2.664535e-17 -3.552714e-17 -2.664535e-17  1.332268e-17
# std    1.002509e+00  1.002509e+00  1.002509e+00  1.002509e+00  1.002509e+00
# min   -2.181245e+00 -1.249784e+00 -5.179593e-01 -8.410128e-01 -7.333440e-01
# 25%   -9.409310e-01 -1.249784e+00 -5.179593e-01 -8.410128e-01 -7.333440e-01
# 50%    1.950352e-01  1.059757e-01 -5.179593e-01 -4.015041e-01 -6.504393e-01
# 75%    8.163779e-01  1.015798e+00  8.784106e-02  5.249112e-01  7.511685e-01
# max    2.125466e+00  1.516960e+00  4.463066e+00  2.640585e+00  3.670969e+00
#
#        ...         V9953         V9961         V9967         V9968  \
# count  ...  2.000000e+02  2.000000e+02  2.000000e+02  2.000000e+02
# mean   ... -2.220446e-18 -2.220446e-17  8.881784e-18 -8.881784e-18
# std    ...  1.002509e+00  1.002509e+00  1.002509e+00  1.002509e+00
# min    ... -5.746099e-01 -3.013826e-01 -5.945668e-01 -7.392526e-01
# 25%    ... -5.746099e-01 -3.013826e-01 -5.945668e-01 -7.198666e-01
# 50%    ... -5.746099e-01 -3.013826e-01 -3.548221e-01 -4.032287e-01
# 75%    ...  1.959762e-01 -3.013826e-01  8.818435e-02  2.171231e-01
# max    ...  4.638738e+00  7.923984e+00  6.014048e+00  4.197714e+00
#
#               V9969         V9972         V9976       V9988         V9993  \
# count  2.000000e+02  2.000000e+02  2.000000e+02  200.000000  2.000000e+02
# mean   3.552714e-17  3.108624e-17  1.776357e-17    0.000000  1.998401e-17
# std    1.002509e+00  1.002509e+00  1.002509e+00    1.002509  1.002509e+00
# min   -1.443478e-01 -4.268055e-01 -4.815630e-01   -0.987873 -9.451913e-01
# 25%   -1.443478e-01 -4.268055e-01 -4.815630e-01   -0.660763 -9.451913e-01
# 50%   -1.443478e-01 -4.268055e-01 -4.815630e-01   -0.313208 -1.873998e-01
# 75%   -1.443478e-01 -4.268055e-01  5.417583e-02    0.305235  7.137577e-01
# max    1.231044e+01  5.548471e+00  5.513896e+00    4.348114  3.150979e+00
#
#               V9999
# count  2.000000e+02
# mean  -3.330669e-17
# std    1.002509e+00
# min   -7.910722e-01
# 25%   -7.910722e-01
# 50%   -4.448404e-01
# 75%    6.410684e-01
# max    3.624507e+00
#
# [8 rows x 3786 columns]
#
# Dataset missing values count:
# 0
#
# Constant features count:
# 0
#
# Labels description:
# count    200.000000
# mean       0.560000
# std        0.497633
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# dtype: float64
#
# Labels missing values count:
# 0

# %%
print_target_distribution_info(data_interface.data)
figure = figure_target_distribution(data_interface.data)
# Out:
#    Count  Percentage
# 1    112        56.0
# 0     88        44.0

# %%
figure = figure_feature_distributions(data_interface.data, 9)

# %%
figure = figure_correlation_matrix(data_interface.data, 200)

# %%
figure = figure_tsne(data_interface.data)

# %%
feature_importance = feature_variance_explained(data_interface.data)
print(feature_importance)
# Out:
# Feature Variance Explained:
#        Variance Explained
# V7816            0.013643
# V4165            0.013609
# V3671            0.013608
# V8347            0.013492
# V7690            0.013491
# ...                   ...
# V215             0.007040
# V363             0.006973
# V2525            0.006973
# V1730            0.006748
# V143             0.006333
#
# [3786 rows x 1 columns]
